# %%
from IPython.display import IFrame

powerBiEmbed = 'https://app.powerbi.com/view?r=eyJrIjoiMTgxYTY1MzItMjc3MS00MDJlLWJiMTUtMjk4\
M2VjNmU4MjI3IiwidCI6IjRlZmE3NzhmLTVmNmMtNDAxZS04OGFmLWNmMTliZDA5ZDE0OCIsImMiOjN9'

IFrame(powerBiEmbed, width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://app.powerbi.com/view?r=eyJrIjoiMTgxYTY1MzItMjc3MS00MDJlLWJiMTUtMjk4M2VjNmU4MjI3IiwidCI6IjRlZmE3NzhmLTVmNmMtNDAxZS04OGFmLWNmMTliZDA5ZDE0OCIsImMiOjN9"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
